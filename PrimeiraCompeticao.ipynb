# %% [markdown]
# <a href="https://colab.research.google.com/github/AleOi2/Competitions/blob/master/PrimeiraCompeticao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conectando  CoLab com Kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-190e9c25-0e2f-43ad-af9d-4273986cd714" name="files[]" multiple disabled />
#      <output id="result-190e9c25-0e2f-43ad-af9d-4273986cd714">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"aleoide","key":"5a3f2cd18df4ccc2657a99453a05d1da"}'}

# %%
# !mkdir -p ~/user
# !cp kaggle.json ~/user/
# !chmod 600 ~/user/kaggle.json
# !ls ~/user
# Out:
# kaggle.json

# %%
# !mkdir -p ~/.kaggle

# %%
# !ls -l ~/user
# !cat ~/user/kaggle.json
# Out:
# total 4
# -rw------- 1 root root 63 Aug 25 23:23 kaggle.json
# {"username":"aleoide","key":"5a3f2cd18df4ccc2657a99453a05d1da"}

# %%
# !pip install -q kaggle
# !pip install -q kaggle-cli
# Out:
#      |████████████████████████████████| 81kB 2.8MB/s
#      |████████████████████████████████| 5.3MB 7.1MB/s
#      |████████████████████████████████| 112kB 42.2MB/s
#      |████████████████████████████████| 102kB 26.4MB/s
#      |████████████████████████████████| 51kB 3.7MB/s
#   Building wheel for kaggle-cli (setup.py) ... done
#   Building wheel for pyperclip (setup.py) ... done

# %%
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       2840           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      11132           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       4399           False
# imagenet-object-localization-challenge         2029-12-31 07:00:00  Research         Knowledge         50           False
# competitive-data-science-predict-future-sales  2019-12-31 23:59:00  Playground           Kudos       4002           False
# cat-in-the-dat                                 2019-12-09 23:59:00  Playground            Swag         66           False
# understanding_cloud_organization               2019-11-18 23:59:00  Research           $10,000        126           False
# severstal-steel-defect-detection               2019-10-24 23:59:00  Featured          $120,000        806           False
# kuzushiji-recognition                          2019-10-14 23:59:00  Playground         $15,000        140           False
# youtube8m-2019                                 2019-10-11 23:59:00  Research           $25,000        219           False
# ieee-fraud-detection                           2019-10-01 23:59:00  Research           $20,000       3536            True
# open-images-2019-object-detection              2019-10-01 23:59:00  Research           $25,000        449           False
# open-images-2019-visual-relationship           2019-10-01 23:59:00  Research           $25,000        144           False
# open-images-2019-instance-segmentation         2019-10-01 23:59:00  Research           $25,000         88           False
# recursion-cellular-image-classification        2019-09-26 23:59:00  Research           $13,000        669           False
# aptos2019-blindness-detection                  2019-09-05 23:59:00  Featured           $50,000       2751           False
# ciphertext-challenge-iii                       2019-09-05 23:59:00  Playground            Swag         78           False
# siim-acr-pneumothorax-segmentation             2019-09-04 23:59:00  Featured           $30,000       1446           False
# generative-dog-images                          2019-08-31 23:59:00  Research           $10,000        927           False
# champs-scalar-coupling                         2019-08-28 23:59:00  Featured           $30,000       2693           False

# %%
# !kaggle competitions download -c ieee-fraud-detection
# Out:
# Downloading train_transaction.csv.zip to /root/kaggle
#  61% 32.0M/52.5M [00:00<00:00, 103MB/s]
# 100% 52.5M/52.5M [00:00<00:00, 174MB/s]
# Downloading train_identity.csv.zip to /root/kaggle
#   0% 0.00/3.02M [00:00<?, ?B/s]
# 100% 3.02M/3.02M [00:00<00:00, 99.1MB/s]
# Downloading test_transaction.csv.zip to /root/kaggle
#  91% 43.0M/47.3M [00:00<00:00, 188MB/s]
# 100% 47.3M/47.3M [00:00<00:00, 185MB/s]
# Downloading test_identity.csv.zip to /root/kaggle
#   0% 0.00/2.97M [00:00<?, ?B/s]
# 100% 2.97M/2.97M [00:00<00:00, 201MB/s]
# Downloading sample_submission.csv.zip to /root/kaggle
#   0% 0.00/1.14M [00:00<?, ?B/s]
# 100% 1.14M/1.14M [00:00<00:00, 160MB/s]

# %%
import zipfile
path = '/root/kaggle/'
directory_to_extract_to = '/root/user/'
os.chdir('/root/kaggle/')
os.listdir()

arquivos = [re.findall('.*\.zip', file) for file in os.listdir()]
for file in arquivos:
  if file != []:
    path_to_zip_file = path + file[0]
    with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
      zip_ref.extractall(directory_to_extract_to)

# %% [markdown]
# # Análise de Dados

# %%
import pandas as pd
test = pd.read_csv('~/user/test_identity.csv')
test
# Out:
#         TransactionID  id_01  ...  DeviceType                          DeviceInfo
# 0             3663586  -45.0  ...      mobile         MYA-L13 Build/HUAWEIMYA-L13
# 1             3663588    0.0  ...      mobile                LGLS676 Build/MXB48T
# 2             3663597   -5.0  ...     desktop                         Trident/7.0
# 3             3663601  -45.0  ...      mobile         MYA-L13 Build/HUAWEIMYA-L13
# 4             3663602  -95.0  ...      mobile                SM-G9650 Build/R16NW
# 5             3663622   -5.0  ...      mobile                          iOS Device
# 6             3663624   -5.0  ...      mobile                          iOS Device
# 7             3663626   -5.0  ...      mobile                          iOS Device
# 8             3663629   -5.0  ...      mobile                          iOS Device
# 9             3663658   -5.0  ...      mobile                          iOS Device
# 10            3663669   -5.0  ...     desktop                             Windows
# 11            3663677    0.0  ...     desktop                         Trident/7.0
# 12            3663693   -5.0  ...      mobile                          iOS Device
# 13            3663702   -5.0  ...     desktop                             Windows
# 14            3663704   -5.0  ...     desktop                             Windows
# 15            3663708    0.0  ...     desktop                               MacOS
# 16            3663710   -5.0  ...     desktop                                 NaN
# 17            3663714  -10.0  ...      mobile                                 NaN
# 18            3663715  -45.0  ...      mobile         RNE-L03 Build/HUAWEIRNE-L03
# 19            3663716  -10.0  ...      mobile                       MotoE2(4G-LTE
# 20            3663737  -20.0  ...      mobile                                 NaN
# 21            3663744   -5.0  ...      mobile                          iOS Device
# 22            3663747   -5.0  ...      mobile          Lenovo K33b36 Build/NRD90N
# 23            3663754   -5.0  ...      mobile          Lenovo PB1-750M Build/S100
# 24            3663755   -5.0  ...      mobile  HUAWEI CUN-L03 Build/HUAWEICUN-L03
# 25            3663758   -5.0  ...     desktop                             Windows
# 26            3663769   -5.0  ...      mobile               SM-G610M Build/NRD90M
# 27            3663773  -15.0  ...         NaN                                 NaN
# 28            3663778  -15.0  ...         NaN                                 NaN
# 29            3663780  -15.0  ...         NaN                                 NaN
# ...               ...    ...  ...         ...                                 ...
# 141877        4170150  -10.0  ...      mobile                            SM-J600G
# 141878        4170151  -35.0  ...      mobile                                 NaN
# 141879        4170152   -5.0  ...     desktop                               MacOS
# 141880        4170154  -45.0  ...      mobile        SAMSUNG SM-G965U Build/R16NW
# 141881        4170156  -10.0  ...     desktop                               MacOS
# 141882        4170157   -5.0  ...     desktop                             Windows
# 141883        4170170  -45.0  ...      mobile                                 NaN
# 141884        4170172  -45.0  ...      mobile                            SM-G570M
# 141885        4170173  -10.0  ...      mobile                            SM-J600G
# 141886        4170177  -10.0  ...      mobile                            SM-J600G
# 141887        4170180  -10.0  ...      mobile                            SM-J600G
# 141888        4170184   -5.0  ...      mobile                           Alpha 950
# 141889        4170185   -5.0  ...      mobile                          iOS Device
# 141890        4170187   -5.0  ...      mobile             Moto C Build/NRD90M.070
# 141891        4170188   -5.0  ...      mobile       SAMSUNG SM-A730F Build/NMF26X
# 141892        4170192   -5.0  ...      mobile             Moto C Build/NRD90M.070
# 141893        4170200   -5.0  ...     desktop                         Trident/7.0
# 141894        4170214   -5.0  ...     desktop                             Windows
# 141895        4170219   -5.0  ...     desktop                             Windows
# 141896        4170223   -5.0  ...      mobile                             ANE-LX3
# 141897        4170224  -35.0  ...      mobile                                 NaN
# 141898        4170225   -5.0  ...     desktop                             Windows
# 141899        4170226   -5.0  ...      mobile                             LG-M250
# 141900        4170228  -10.0  ...      mobile                     Moto G (5) Plus
# 141901        4170229   -5.0  ...     desktop                                 NaN
# 141902        4170230  -20.0  ...      mobile                            SM-J700M
# 141903        4170233   -5.0  ...      mobile                            SM-J320M
# 141904        4170234   -5.0  ...      mobile                          iOS Device
# 141905        4170236  -45.0  ...      mobile         ALE-L23 Build/HuaweiALE-L23
# 141906        4170239  -10.0  ...      mobile                             SAMSUNG
#
# [141907 rows x 41 columns]

# %%
# !git clone https://github.com/fastai/courses.git
